# %% [markdown]
# # Audiobooks business case

# %% [markdown]
# ### Problem
#
# You are given data from an Audiobook App. Logically, it relates to the audio versions of books ONLY. Each customer in the database has made a purchase at least once, that's why he/she is in the database. We want to create a machine learning algorithm based on our available data that can predict if a customer will buy again from the Audiobook company.
#
# The main idea is that if a customer has a low probability of coming back, there is no reason to spend any money on advertising to him/her. If we can focus our efforts SOLELY on customers that are likely to convert again, we can make great savings. Moreover, this model can identify the most important metrics for a customer to come back again. Identifying new customers creates value and growth opportunities.
#
# You have a .csv summarizing the data. There are several variables: Customer ID, ), Book length overall (sum of the minute length of all purchases), Book length avg (average length in minutes of all purchases), Price paid_overall (sum of all purchases) ,Price Paid avg (average of all purchases), Review (a Boolean variable whether the customer left a review), Review out of 10 (if the customer left a review, his/her review out of 10, Total minutes listened, Completion (from 0 to 1), Support requests (number of support requests; everything from forgotten password to assistance for using the App), and Last visited minus purchase date (in days).
#
# These are the inputs (excluding customer ID, as it is completely arbitrary. It's more like a name, than a number).
#
# The targets are a Boolean variable (0 or 1). We are taking a period of 2 years in our inputs, and the next 6 months as targets. So, in fact, we are predicting if: based on the last 2 years of activity and engagement, a customer will convert in the next 6 months. 6 months sounds like a reasonable time. If they don't convert after 6 months, chances are they've gone to a competitor or didn't like the Audiobook way of digesting information.
#
# The task is simple: create a machine learning algorithm, which is able to predict if a customer will buy again.
#
# This is a classification problem with two classes: won't buy and will buy, represented by 0s and 1s.
#
# Good luck!

# %% [markdown]
# ## Create a class that will batch the data
#
# Whenever you want to batch the data you need to have appropriate methods. There are some batching methods integrated in TensorFlow and sklearn, but some problems may need specific coding.
#
# Here we show how these methods look like. You can use them for any machine learning framework you need (directly or after little fine-tuning).

# %%
import numpy as np

# Create a class that will do the batching for the algorithm
# Contains 3 functions, '__init__', '__next__', '__iter__', (this class is basically an iterator)
class Audiobooks_Data_Reader():
    # Dataset is a mandatory arugment, while the batch_size is optional
    # If you don't input batch_size, it will automatically take the value: None
    def __init__(self, dataset, batch_size = None):
    
        # The dataset that loads is one of "train", "validation", "test".
        # e.g. if I call this class with x('train',5), it will load 'Audiobooks_data_train.npz' with a batch size of 5.
        npz = np.load('Audiobooks_data_{0}.npz'.format(dataset))
        
        # Two variables that take the values of the inputs and the targets. Inputs are floats, targets are integers
        self.inputs, self.targets = npz['inputs'].astype(np.float), npz['targets'].astype(np.int)
        
        # Counts the batch number, given the size you feed it later
        # If the batch size is None, we are either validating or testing, so we want to take the data in a single batch
        if batch_size is None:
            self.batch_size = self.inputs.shape[0]
        else:
            self.batch_size = batch_size
        self.curr_batch = 0
        self.batch_count = self.inputs.shape[0] // self.batch_size
    
    # A method which loads the next batch
    def __next__(self):
        if self.curr_batch >= self.batch_count:
            self.curr_batch = 0
            raise StopIteration()
            
        # You slice the dataset in batches and then the "next" function loads them one after the other
        batch_slice = slice(self.curr_batch * self.batch_size, (self.curr_batch + 1) * self.batch_size)
        inputs_batch = self.inputs[batch_slice]
        targets_batch = self.targets[batch_slice]
        self.curr_batch += 1
        
        # One-hot encode the targets.
        classes_num = 2
        targets_one_hot = np.zeros((targets_batch.shape[0], classes_num))
        targets_one_hot[range(targets_batch.shape[0]), targets_batch] = 1
        
        # The function will return the inputs batch and the one-hot encoded targets
        return inputs_batch, targets_one_hot
    
        
    # A method needed for iterating over the batches, as we will put them in a loop
    # This tells Python that the class we're defining is iterable, i.e. that we can use it like:
    # for input, output in data: 
        # do things
    # An iterator in Python is a class with a method __next__ that defines exactly how to iterate through its objects
    def __iter__(self):
        return self

# %% [markdown]
# ## Create the machine learning algorithm
#
# We will create an algorithm which is essentially copy-pasting the MNIST code and we will simply adjust where needed.
# Once more, I will put the whole code in one piece as we can simply rerun the cell and train a new model. That's because the whole algorithm is contained in the cell and we have the tf.reset_default_graph() function.

# %%
# We need to import TF (we didn't need it so far)
import tensorflow as tf

# Input size depends on the number of input variables. We have 10 of them
input_size = 10
# Output size is 2, as we one-hot encoded the targets.
output_size = 2
# Choose a hidden_layer_size
hidden_layer_size = 50

# Reset the default graph, so you can fiddle with the hyperparameters and then rerun the code.
tf.compat.v1.reset_default_graph()

# Create the placeholders
inputs = tf.compat.v1.placeholder(tf.float32, [None, input_size])
targets = tf.compat.v1.placeholder(tf.int32, [None, output_size])

# Outline the model. We will create a net with 2 hidden layers
weights_1 = tf.compat.v1.get_variable("weights_1", [input_size, hidden_layer_size])
biases_1 = tf.compat.v1.get_variable("biases_1", [hidden_layer_size])
outputs_1 = tf.nn.relu(tf.matmul(inputs, weights_1) + biases_1)

weights_2 = tf.compat.v1.get_variable("weights_2", [hidden_layer_size, hidden_layer_size])
biases_2 = tf.compat.v1.get_variable("biases_2", [hidden_layer_size])
outputs_2 = tf.nn.sigmoid(tf.matmul(outputs_1, weights_2) + biases_2)

weights_3 = tf.compat.v1.get_variable("weights_3", [hidden_layer_size, output_size])
biases_3 = tf.compat.v1.get_variable("biases_3", [output_size])
# We will incorporate the softmax activation into the loss, as in the previous example
outputs = tf.matmul(outputs_2, weights_3) + biases_3

# Use the softmax cross entropy loss with logits
loss = tf.nn.softmax_cross_entropy_with_logits(logits=outputs, labels=targets)
mean_loss = tf.reduce_mean(loss)

# Get a 0 or 1 for every input indicating whether it output the correct answer
out_equals_target = tf.equal(tf.argmax(outputs, 1), tf.argmax(targets, 1))
accuracy = tf.reduce_mean(tf.cast(out_equals_target, tf.float32))

# Optimize with Adam
optimize = tf.compat.v1.train.AdamOptimizer(learning_rate=0.0001).minimize(mean_loss)

# Create a session
sess = tf.compat.v1.InteractiveSession()

# Initialize the variables
initializer = tf.compat.v1.global_variables_initializer()
sess.run(initializer)

# Choose the batch size
batch_size = 100

# Set early stopping mechanisms
max_epochs = 100
prev_validation_loss = 9999999.

# Load the first batch of training and validation, using the class we created. 
# Arguments are ending of 'Audiobooks_Data_<...>', where for <...> we input 'train', 'validation', or 'test'
# depending on what we want to load
train_data = Audiobooks_Data_Reader('train', batch_size)
validation_data = Audiobooks_Data_Reader('validation')

# Create the loop for epochs 
for epoch_counter in range(max_epochs):
    
    # Set the epoch loss to 0, and make it a float
    curr_epoch_loss = 0.
    
    # Iterate over the training data 
    # Since train_data is an instance of the Audiobooks_Data_Reader class,
    # we can iterate through it by implicitly using the __next__ method we defined above.
    # As a reminder, it batches samples together, one-hot encodes the targets, and returns
    # inputs and targets batch by batch
    for input_batch, target_batch in train_data:
        _, batch_loss = sess.run([optimize, mean_loss], 
            feed_dict={inputs: input_batch, targets: target_batch})
        
        #Record the batch loss into the current epoch loss
        curr_epoch_loss += batch_loss
    
    # Find the mean curr_epoch_loss
    # batch_count is a variable, defined in the Audiobooks_Data_Reader class
    curr_epoch_loss /= train_data.batch_count
    
    # Set validation loss and accuracy for the epoch to zero
    validation_loss = 0.
    validation_accuracy = 0.
    
    # Use the same logic of the code to forward propagate the validation set
    # There will be a single batch, as the class was created in this way
    for input_batch, target_batch in validation_data:
        validation_loss, validation_accuracy = sess.run([mean_loss, accuracy],
            feed_dict={inputs: input_batch, targets: target_batch})
    
    # Print statistics for the current epoch
    print('Epoch '+str(epoch_counter+1)+
          '. Training loss: '+'{0:.3f}'.format(curr_epoch_loss)+
          '. Validation loss: '+'{0:.3f}'.format(validation_loss)+
          '. Validation accuracy: '+'{0:.2f}'.format(validation_accuracy * 100.)+'%')
    
    # Trigger early stopping if validation loss begins increasing.
    if validation_loss > prev_validation_loss:
        break
        
    # Store this epoch's validation loss to be used as previous in the next iteration.
    prev_validation_loss = validation_loss
    
print('End of training.')
# Out:
# C:\Users\iolley2\Anaconda3\envs\py3-TF1\lib\site-packages\tensorflow\python\client\session.py:1735: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# C:\Users\iolley2\Anaconda3\envs\py3-TF1\lib\site-packages\ipykernel_launcher.py:15: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from ipykernel import kernelapp as app
# C:\Users\iolley2\Anaconda3\envs\py3-TF1\lib\site-packages\ipykernel_launcher.py:15: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from ipykernel import kernelapp as app
# Epoch 1. Training loss: 1.083. Validation loss: 1.041. Validation accuracy: 48.99%
# Epoch 2. Training loss: 0.982. Validation loss: 0.949. Validation accuracy: 48.99%
# Epoch 3. Training loss: 0.897. Validation loss: 0.871. Validation accuracy: 48.99%
# Epoch 4. Training loss: 0.827. Validation loss: 0.808. Validation accuracy: 48.99%
# Epoch 5. Training loss: 0.771. Validation loss: 0.759. Validation accuracy: 48.99%
# Epoch 6. Training loss: 0.728. Validation loss: 0.720. Validation accuracy: 49.66%
# Epoch 7. Training loss: 0.694. Validation loss: 0.690. Validation accuracy: 49.89%
# Epoch 8. Training loss: 0.668. Validation loss: 0.666. Validation accuracy: 51.90%
# Epoch 9. Training loss: 0.648. Validation loss: 0.647. Validation accuracy: 56.60%
# Epoch 10. Training loss: 0.632. Validation loss: 0.632. Validation accuracy: 60.18%
# Epoch 11. Training loss: 0.618. Validation loss: 0.619. Validation accuracy: 63.53%
# Epoch 12. Training loss: 0.606. Validation loss: 0.608. Validation accuracy: 66.67%
# Epoch 13. Training loss: 0.596. Validation loss: 0.598. Validation accuracy: 70.25%
# Epoch 14. Training loss: 0.586. Validation loss: 0.588. Validation accuracy: 70.02%
# Epoch 15. Training loss: 0.577. Validation loss: 0.580. Validation accuracy: 71.14%
# Epoch 16. Training loss: 0.569. Validation loss: 0.572. Validation accuracy: 70.47%
# Epoch 17. Training loss: 0.561. Validation loss: 0.564. Validation accuracy: 70.47%
# Epoch 18. Training loss: 0.553. Validation loss: 0.557. Validation accuracy: 71.14%
# Epoch 19. Training loss: 0.546. Validation loss: 0.550. Validation accuracy: 70.92%
# Epoch 20. Training loss: 0.538. Validation loss: 0.543. Validation accuracy: 72.04%
# Epoch 21. Training loss: 0.532. Validation loss: 0.537. Validation accuracy: 72.04%
# Epoch 22. Training loss: 0.525. Validation loss: 0.530. Validation accuracy: 72.04%
# Epoch 23. Training loss: 0.519. Validation loss: 0.525. Validation accuracy: 72.71%
# Epoch 24. Training loss: 0.513. Validation loss: 0.519. Validation accuracy: 72.93%
# Epoch 25. Training loss: 0.507. Validation loss: 0.514. Validation accuracy: 73.60%
# Epoch 26. Training loss: 0.501. Validation loss: 0.509. Validation accuracy: 73.83%
# Epoch 27. Training loss: 0.496. Validation loss: 0.504. Validation accuracy: 73.83%
# Epoch 28. Training loss: 0.491. Validation loss: 0.499. Validation accuracy: 73.83%
# Epoch 29. Training loss: 0.486. Validation loss: 0.495. Validation accuracy: 74.05%
# Epoch 30. Training loss: 0.481. Validation loss: 0.490. Validation accuracy: 74.50%
# Epoch 31. Training loss: 0.477. Validation loss: 0.486. Validation accuracy: 73.83%
# Epoch 32. Training loss: 0.472. Validation loss: 0.483. Validation accuracy: 73.15%
# Epoch 33. Training loss: 0.468. Validation loss: 0.479. Validation accuracy: 73.60%
# Epoch 34. Training loss: 0.464. Validation loss: 0.475. Validation accuracy: 73.83%
# Epoch 35. Training loss: 0.461. Validation loss: 0.472. Validation accuracy: 73.38%
# Epoch 36. Training loss: 0.457. Validation loss: 0.469. Validation accuracy: 73.83%
# Epoch 37. Training loss: 0.453. Validation loss: 0.466. Validation accuracy: 73.60%
# Epoch 38. Training loss: 0.450. Validation loss: 0.463. Validation accuracy: 73.60%
# Epoch 39. Training loss: 0.447. Validation loss: 0.460. Validation accuracy: 73.38%
# Epoch 40. Training loss: 0.444. Validation loss: 0.457. Validation accuracy: 73.38%
# Epoch 41. Training loss: 0.441. Validation loss: 0.455. Validation accuracy: 73.38%
# Epoch 42. Training loss: 0.438. Validation loss: 0.452. Validation accuracy: 73.38%
# Epoch 43. Training loss: 0.435. Validation loss: 0.450. Validation accuracy: 73.60%
# Epoch 44. Training loss: 0.433. Validation loss: 0.447. Validation accuracy: 73.83%
# Epoch 45. Training loss: 0.430. Validation loss: 0.445. Validation accuracy: 74.05%
# Epoch 46. Training loss: 0.428. Validation loss: 0.443. Validation accuracy: 74.27%
# Epoch 47. Training loss: 0.426. Validation loss: 0.441. Validation accuracy: 74.27%
# Epoch 48. Training loss: 0.423. Validation loss: 0.439. Validation accuracy: 74.27%
# Epoch 49. Training loss: 0.421. Validation loss: 0.437. Validation accuracy: 74.27%
# Epoch 50. Training loss: 0.419. Validation loss: 0.435. Validation accuracy: 74.27%
# Epoch 51. Training loss: 0.417. Validation loss: 0.434. Validation accuracy: 74.05%
# Epoch 52. Training loss: 0.415. Validation loss: 0.432. Validation accuracy: 74.05%
# Epoch 53. Training loss: 0.413. Validation loss: 0.430. Validation accuracy: 74.05%
# Epoch 54. Training loss: 0.411. Validation loss: 0.428. Validation accuracy: 74.94%
# Epoch 55. Training loss: 0.410. Validation loss: 0.427. Validation accuracy: 75.17%
# Epoch 56. Training loss: 0.408. Validation loss: 0.425. Validation accuracy: 74.94%
# Epoch 57. Training loss: 0.406. Validation loss: 0.424. Validation accuracy: 75.17%
# Epoch 58. Training loss: 0.405. Validation loss: 0.423. Validation accuracy: 75.39%
# Epoch 59. Training loss: 0.403. Validation loss: 0.421. Validation accuracy: 75.39%
# Epoch 60. Training loss: 0.402. Validation loss: 0.420. Validation accuracy: 75.39%
# Epoch 61. Training loss: 0.400. Validation loss: 0.418. Validation accuracy: 75.84%
# Epoch 62. Training loss: 0.399. Validation loss: 0.417. Validation accuracy: 75.84%
# Epoch 63. Training loss: 0.397. Validation loss: 0.416. Validation accuracy: 76.06%
# Epoch 64. Training loss: 0.396. Validation loss: 0.415. Validation accuracy: 76.06%
# Epoch 65. Training loss: 0.395. Validation loss: 0.413. Validation accuracy: 76.06%
# Epoch 66. Training loss: 0.393. Validation loss: 0.412. Validation accuracy: 76.06%
# Epoch 67. Training loss: 0.392. Validation loss: 0.411. Validation accuracy: 76.06%
# Epoch 68. Training loss: 0.391. Validation loss: 0.410. Validation accuracy: 76.06%
# Epoch 69. Training loss: 0.390. Validation loss: 0.409. Validation accuracy: 76.06%
# Epoch 70. Training loss: 0.388. Validation loss: 0.408. Validation accuracy: 76.29%
# Epoch 71. Training loss: 0.387. Validation loss: 0.407. Validation accuracy: 76.29%
# Epoch 72. Training loss: 0.386. Validation loss: 0.406. Validation accuracy: 75.84%
# Epoch 73. Training loss: 0.385. Validation loss: 0.405. Validation accuracy: 75.84%
# Epoch 74. Training loss: 0.384. Validation loss: 0.404. Validation accuracy: 75.84%
# Epoch 75. Training loss: 0.383. Validation loss: 0.403. Validation accuracy: 76.29%
# Epoch 76. Training loss: 0.382. Validation loss: 0.402. Validation accuracy: 76.29%
# Epoch 77. Training loss: 0.381. Validation loss: 0.401. Validation accuracy: 76.29%
# Epoch 78. Training loss: 0.380. Validation loss: 0.400. Validation accuracy: 76.29%
# Epoch 79. Training loss: 0.379. Validation loss: 0.399. Validation accuracy: 76.29%
# Epoch 80. Training loss: 0.378. Validation loss: 0.398. Validation accuracy: 76.29%
# Epoch 81. Training loss: 0.377. Validation loss: 0.397. Validation accuracy: 76.51%
# Epoch 82. Training loss: 0.376. Validation loss: 0.397. Validation accuracy: 76.51%
# Epoch 83. Training loss: 0.375. Validation loss: 0.396. Validation accuracy: 76.73%
# Epoch 84. Training loss: 0.374. Validation loss: 0.395. Validation accuracy: 76.51%
# Epoch 85. Training loss: 0.373. Validation loss: 0.394. Validation accuracy: 76.06%
# Epoch 86. Training loss: 0.372. Validation loss: 0.394. Validation accuracy: 76.06%
# Epoch 87. Training loss: 0.372. Validation loss: 0.393. Validation accuracy: 76.29%
# Epoch 88. Training loss: 0.371. Validation loss: 0.392. Validation accuracy: 76.73%
# Epoch 89. Training loss: 0.370. Validation loss: 0.391. Validation accuracy: 76.73%
# Epoch 90. Training loss: 0.369. Validation loss: 0.391. Validation accuracy: 76.96%
# Epoch 91. Training loss: 0.368. Validation loss: 0.390. Validation accuracy: 76.96%
# Epoch 92. Training loss: 0.368. Validation loss: 0.389. Validation accuracy: 76.96%
# Epoch 93. Training loss: 0.367. Validation loss: 0.389. Validation accuracy: 76.96%
# Epoch 94. Training loss: 0.366. Validation loss: 0.388. Validation accuracy: 76.96%
# Epoch 95. Training loss: 0.365. Validation loss: 0.388. Validation accuracy: 76.96%
# Epoch 96. Training loss: 0.365. Validation loss: 0.387. Validation accuracy: 76.96%
# Epoch 97. Training loss: 0.364. Validation loss: 0.386. Validation accuracy: 77.18%
# Epoch 98. Training loss: 0.363. Validation loss: 0.386. Validation accuracy: 77.18%
# Epoch 99. Training loss: 0.363. Validation loss: 0.385. Validation accuracy: 77.40%
# Epoch 100. Training loss: 0.362. Validation loss: 0.385. Validation accuracy: 77.40%
# End of training.

# %% [markdown]
# ## Test the model

# %%
# Load the test data, following the same logic as we did for the train_data and validation data
test_data = Audiobooks_Data_Reader('test')

# Forward propagate through the training set. This time we only need the accuracy
for inputs_batch, targets_batch in test_data:
    test_accuracy = sess.run([accuracy],
                     feed_dict={inputs: inputs_batch, targets: targets_batch})

# Get the test accuracy in percentages
# When sess.run is has a single output, we get a list (that's how it was coded by Google), rather than a float.
# Therefore, we must take the first value from the list (the value at position 0)
test_accuracy_percent = test_accuracy[0] * 100.

# Print the test accuracy
print('Test accuracy: '+'{0:.2f}'.format(test_accuracy_percent)+'%')
# Out:
# Test accuracy: 79.24%
# C:\Users\iolley2\Anaconda3\envs\py3-TF1\lib\site-packages\ipykernel_launcher.py:15: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from ipykernel import kernelapp as app
# C:\Users\iolley2\Anaconda3\envs\py3-TF1\lib\site-packages\ipykernel_launcher.py:15: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from ipykernel import kernelapp as app
